# %% [markdown]
# <a href="https://colab.research.google.com/github/emilyymeloo/Banco-d-Dados/blob/main/C%C3%B3pia_de_Consultas_de_PI3_Monitoria_IFMG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Primeira parte do Trabalho Prático de BD2
#
# > REFERÊNCIA PRINCIPAL (material em construção): https://docs.google.com/presentation/d/1iIXPOhn2TSm5y5Rf5hiI46GTef1E2gKi/edit?usp=sharing&ouid=105327427325994478755&rtpof=true&sd=true
#
#
# Vamos juntar o que vocês já enviaram de PI3 com a atividade de revisão que fizemos algumas aulas atrás (link a seguir) <br>
# https://docs.google.com/document/d/1bXAUHBfzFwRp2Rsxn4-Afhm_yPm3Pz1DhQtp_CZz-JQ
#
# Crie um novo script do Google Colab, e comece definindo as funções de execução de queries que vimos nas últimas aulas. <br>
# ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓ ↓

# %%
import sqlite3
from sqlite3 import Error

## Função de alteração (insert, update, delete...)
def execute_query(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        connection.commit()
        print(f"Query {query.split('(')[0].strip()} executada.")
        if cursor.rowcount != -1: print(f"{cursor.rowcount} linha(s) afetadas")

    except Error as e:
        print(f"Erro: '{e}'")


# Função de leitura de dados (select)
def execute_read_query(connection, query):
    cursor = connection.cursor()
    result = None
    try:
        cursor.execute(query)
        result = cursor.fetchall()

        return result
    except Error as e:
        print(f"Erro: '{e}'")

connection = sqlite3.connect("monitoria_ifmg.sqlite")

# %% [markdown]
# # Suas tabelas de PI3
#
# Abra a célula de código que corresponde à sua equipe de PI3, nela estará o SQL de criação de tabelas que foi enviado por vocês em atividades anteriores. Copie o código de execução para o seu script.

# %% [markdown]
# ##Monitoria IFMG

# %% [markdown]
# ###Criação das Tabelas

# %%
query = """
CREATE TABLE usuario (
    ra INTEGER PRIMARY KEY,
    nome VARCHAR(100) NOT NULL,
    email VARCHAR(100) NOT NULL UNIQUE,
    senha VARCHAR(255) NOT NULL,
    tipo TEXT NOT NULL
);
"""

execute_query(connection, query)

query = """
CREATE TABLE aluno (
    ra INT(20) PRIMARY KEY,
    turma VARCHAR(20) NOT NULL,
    FOREIGN KEY (ra) REFERENCES usuario(ra)
);
"""

execute_query(connection, query)

query = """
CREATE TABLE monitor (
    ra INT(20) PRIMARY KEY,
    FOREIGN KEY (ra) REFERENCES aluno(ra)
);
"""

execute_query(connection, query)

query = """
CREATE TABLE auditoria_admin (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    ra_admin_origem INT(20) NOT NULL,
    ra_usuario_promovido INT(20) NOT NULL,
    data_promocao DATETIME NOT NULL,
    FOREIGN KEY (ra_admin_origem) REFERENCES usuario(ra),
    FOREIGN KEY (ra_usuario_promovido) REFERENCES usuario(ra)
);
"""

execute_query(connection, query)

query = """
CREATE TABLE comunicado (
    id_comunicado INTEGER PRIMARY KEY AUTOINCREMENT,
    titulo VARCHAR(150) NOT NULL,
    conteudo TEXT NOT NULL,
    data_publicacao DATETIME NOT NULL,
    ra_admin INT(20) NOT NULL,
    FOREIGN KEY (ra_admin) REFERENCES usuario(ra)
);
"""

execute_query(connection, query)

query = """
CREATE TABLE monitoria (
    id_monitoria INTEGER PRIMARY KEY AUTOINCREMENT,
    disciplina VARCHAR(100) NOT NULL,
    local VARCHAR(100) NOT NULL,
    horario VARCHAR(50) NOT NULL,
    ra_monitor INT(20) NOT NULL,
    FOREIGN KEY (ra_monitor) REFERENCES monitor(ra)
);
"""

execute_query(connection, query)

query = """
CREATE TABLE aula_monitoria (
    id_aula INTEGER PRIMARY KEY AUTOINCREMENT,
    data_aula DATE NOT NULL,
    id_monitoria INT NOT NULL,
    FOREIGN KEY (id_monitoria) REFERENCES monitoria(id_monitoria)
);
"""

execute_query(connection, query)

query = """
CREATE TABLE presenca (
    id_presenca INTEGER PRIMARY KEY AUTOINCREMENT,
    id_aula INT NOT NULL,
    ra_aluno INT(20) NOT NULL,
    FOREIGN KEY (id_aula) REFERENCES aula_monitoria(id_aula),
    FOREIGN KEY (ra_aluno) REFERENCES aluno(ra),
    UNIQUE (id_aula, ra_aluno)
);
"""

execute_query(connection, query)

query = """
CREATE TABLE blog_monitoria (
    id_blog INTEGER PRIMARY KEY AUTOINCREMENT,
    id_monitoria INT NOT NULL,
    FOREIGN KEY (id_monitoria) REFERENCES monitoria(id_monitoria)
);
"""

execute_query(connection, query)

query = """
CREATE TABLE postagem_discussao (
    id_postagem INTEGER PRIMARY KEY AUTOINCREMENT,
    id_blog INT NOT NULL,
    ra_usuario INT(20) NOT NULL,
    nome_usuario VARCHAR(100) NOT NULL,
    conteudo TEXT NOT NULL,
    data_postagem DATETIME NOT NULL,
    FOREIGN KEY (id_blog) REFERENCES blog_monitoria(id_blog),
    FOREIGN KEY (ra_usuario) REFERENCES usuario(ra)
);
"""

execute_query(connection, query)

query = """
CREATE TABLE enquete (
    id_enquete INTEGER PRIMARY KEY AUTOINCREMENT,
    id_blog INT NOT NULL,
    titulo VARCHAR(150) NOT NULL,
    data_criacao DATETIME NOT NULL,
    FOREIGN KEY (id_blog) REFERENCES blog_monitoria(id_blog)
);
"""

execute_query(connection, query)

query = """
CREATE TABLE opcao_enquete (
    id_opcao INTEGER PRIMARY KEY AUTOINCREMENT,
    id_enquete INT NOT NULL,
    descricao VARCHAR(100) NOT NULL,
    FOREIGN KEY (id_enquete) REFERENCES enquete(id_enquete)
);
"""

execute_query(connection, query)

query = """
CREATE TABLE resposta_enquete (
    id_resposta INTEGER PRIMARY KEY AUTOINCREMENT,
    id_opcao INT NOT NULL,
    ra_usuario INT(20) NOT NULL,
    FOREIGN KEY (id_opcao) REFERENCES opcao_enquete(id_opcao),
    FOREIGN KEY (ra_usuario) REFERENCES usuario(ra),
    UNIQUE (id_opcao, ra_usuario)
);
"""

execute_query(connection, query)

query = """
CREATE TABLE notificacao (
    id_notificacao INTEGER PRIMARY KEY AUTOINCREMENT,
    id_blog INT NOT NULL,
    titulo VARCHAR(150) NOT NULL,
    conteudo TEXT NOT NULL,
    data_publicacao DATETIME NOT NULL,
    FOREIGN KEY (id_blog) REFERENCES blog_monitoria(id_blog)
);
"""

execute_query(connection, query)

query = """
CREATE TABLE notificacao_usuario (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    id_notificacao INT NOT NULL,
    ra_usuario INT(20) NOT NULL,
    visualizada BOOLEAN DEFAULT FALSE,
    FOREIGN KEY (id_notificacao) REFERENCES notificacao(id_notificacao),
    FOREIGN KEY (ra_usuario) REFERENCES usuario(ra)
);
"""

execute_query(connection, query)
# Out:
# Query CREATE TABLE usuario executada.
# Query CREATE TABLE aluno executada.
# Query CREATE TABLE monitor executada.
# Query CREATE TABLE auditoria_admin executada.
# Query CREATE TABLE comunicado executada.
# Query CREATE TABLE monitoria executada.
# Query CREATE TABLE aula_monitoria executada.
# Query CREATE TABLE presenca executada.
# Query CREATE TABLE blog_monitoria executada.
# Query CREATE TABLE postagem_discussao executada.
# Query CREATE TABLE enquete executada.
# Query CREATE TABLE opcao_enquete executada.
# Query CREATE TABLE resposta_enquete executada.
# Query CREATE TABLE notificacao executada.
# Query CREATE TABLE notificacao_usuario executada.

# %% [markdown]
# ###Inserção de Dados

# %%
query = """
INSERT INTO usuario
VALUES
(1001, 'Gustavo Silva', 'gustavo@ifmg.edu.br', '123', 'ALUNO'),
(1002, 'Marina Costa', 'marina@ifmg.edu.br', '123', 'ALUNO'),
(1003, 'Lucas Almeida', 'lucas@ifmg.edu.br', '123', 'MONITOR'),
(1004, 'Fernanda Souza', 'fernanda@ifmg.edu.br', '123', 'ADMIN'),
(1005, 'Carlos Henrique', 'carlos@ifmg.edu.br', '123', 'ALUNO'),
(1006, 'Ana Beatriz', 'ana@ifmg.edu.br', '123', 'MONITOR');
"""

execute_query(connection, query)

query = """
INSERT INTO aluno
VALUES
(1001, '3A'),
(1002, '2B'),
(1003, '3A'),
(1005, '1C'),
(1006, '2A');
"""

execute_query(connection, query)

query = """
INSERT INTO monitor
VALUES
(1003),
(1006);
"""

execute_query(connection, query)

query = """
INSERT INTO auditoria_admin
(ra_admin_origem, ra_usuario_promovido, data_promocao)

VALUES
(1004, 1003, '2026-06-20 14:00:00'),
(1004, 1006, '2026-06-21 10:30:00');
"""

execute_query(connection, query)

query = """
INSERT INTO comunicado
(titulo, conteudo, data_publicacao, ra_admin)

VALUES
(
'Semana de Provas',
'As monitorias terão horários especiais durante a semana de provas.',
'2026-06-22 08:00:00',
1004
),

(
'Novo Laboratório',
'O laboratório 03 estará disponível para monitorias.',
'2026-06-23 09:00:00',
1004
);
"""

execute_query(connection, query)

query = """
INSERT INTO monitoria
(disciplina, local, horario, ra_monitor)

VALUES
('Banco de Dados', 'Lab 01', '14:00', 1003),
('Matemática', 'Sala 12', '10:00', 1006),
('Programação Web', 'Lab 02', '16:00', 1003);
"""

execute_query(connection, query)

query = """
INSERT INTO aula_monitoria
(data_aula, id_monitoria)

VALUES
('2026-06-20', 1),
('2026-06-21', 1),
('2026-06-22', 2),
('2026-06-23', 3);
"""

execute_query(connection, query)

query = """
INSERT INTO presenca
(id_aula, ra_aluno)

VALUES
(1, 1001),
(1, 1002),
(2, 1005),
(3, 1001),
(4, 1002);
"""

execute_query(connection, query)

query = """
INSERT INTO blog_monitoria
(id_monitoria)

VALUES
(1),
(2),
(3);
"""

execute_query(connection, query)

query = """
INSERT INTO postagem_discussao
(id_blog, ra_usuario, nome_usuario, conteudo, data_postagem)

VALUES
(
1,
1001,
'Gustavo Silva',
'Estou com dúvida em JOIN.',
'2026-06-24 15:00:00'
),

(
2,
1002,
'Marina Costa',
'Alguém entendeu derivada?',
'2026-06-24 16:00:00'
),

(
1,
1003,
'Lucas Almeida',
'Posso ajudar na dúvida sobre JOIN.',
'2026-06-24 17:00:00'
);
"""

execute_query(connection, query)

query = """
INSERT INTO enquete
(id_blog, titulo, data_criacao)

VALUES
(
1,
'Qual horário é melhor para monitoria?',
'2026-06-24 12:00:00'
),

(
2,
'Qual conteúdo tem mais dificuldade?',
'2026-06-24 13:00:00'
);
"""

execute_query(connection, query)

query = """
INSERT INTO opcao_enquete
(id_enquete, descricao)

VALUES
(1, 'Manhã'),
(1, 'Tarde'),
(1, 'Noite'),
(2, 'Funções'),
(2, 'Limites'),
(2, 'Derivadas');
"""

execute_query(connection, query)

query = """
INSERT INTO resposta_enquete
(id_opcao, ra_usuario)

VALUES
(1, 1001),
(2, 1002),
(3, 1005),
(6, 1001);
"""

execute_query(connection, query)

query = """
INSERT INTO notificacao
(id_blog, titulo, conteudo, data_publicacao)

VALUES
(
1,
'Nova postagem',
'Uma nova postagem foi adicionada no blog.',
'2026-06-24 18:00:00'
),

(
2,
'Nova enquete',
'Uma nova enquete foi criada.',
'2026-06-24 18:30:00'
);
"""

execute_query(connection, query)

query = """
INSERT INTO notificacao_usuario
(id_notificacao, ra_usuario, visualizada)

VALUES
(1, 1001, FALSE),
(1, 1002, TRUE),
(2, 1005, FALSE);
"""

execute_query(connection, query)
# Out:
# Erro: 'UNIQUE constraint failed: usuario.ra'
# Erro: 'UNIQUE constraint failed: aluno.ra'
# Erro: 'UNIQUE constraint failed: monitor.ra'
# Query INSERT INTO auditoria_admin executada.
# 2 linha(s) afetadas
# Query INSERT INTO comunicado executada.
# 2 linha(s) afetadas
# Query INSERT INTO monitoria executada.
# 3 linha(s) afetadas
# Query INSERT INTO aula_monitoria executada.
# 4 linha(s) afetadas
# Erro: 'UNIQUE constraint failed: presenca.id_aula, presenca.ra_aluno'
# Query INSERT INTO blog_monitoria executada.
# 3 linha(s) afetadas
# Query INSERT INTO postagem_discussao executada.
# 3 linha(s) afetadas
# Query INSERT INTO enquete executada.
# 2 linha(s) afetadas
# Query INSERT INTO opcao_enquete executada.
# 6 linha(s) afetadas
# Erro: 'UNIQUE constraint failed: resposta_enquete.id_opcao, resposta_enquete.ra_usuario'
# Query INSERT INTO notificacao executada.
# 2 linha(s) afetadas
# Query INSERT INTO notificacao_usuario executada.
# 3 linha(s) afetadas

# %% [markdown]
# # Atividades
#
# Para cada atividade a seguir, copie para o seu script as células de texto e de código indicadas, e altere o que for pedido na questão.
#
# Você pode acessar o material de apoio para relemebrar os conceitos de consultas com SQL: <br>
# https://docs.google.com/presentation/d/1iIXPOhn2TSm5y5Rf5hiI46GTef1E2gKi

# %% [markdown]
# ## Atividade 01
# Crie duas consultas relevantes para sua aplicação em PI3 que tenham, pelo menos, uma função de agregação em cada. Para cada consulta, descreva a ação esperada (ex.: contar participantes em um evento) e justifique o contexto na aplicação de PI3 (ex.: funcionalidade do back-end para checar se já atingiu o limite de vagas do evento).

# %% [markdown]
# **CONSULTA 1**
#
# *Objetivo da consulta (contexto de PI3): **negrito** **negrito**
# Mostrar quantos alunos participaram de cada monitoria cadastrada no sistema.
#
# Descrição da ação esperada ao rodar a consulta:
# A consulta retorna o nome da disciplina e a quantidade de alunos que possuem presença registrada em suas aulas. Essas informações podem ser utilizadas para acompanhar a participação dos alunos nas monitorias.

# %%
Squery = """
SELECT
    m.disciplina,
    COUNT(p.ra_aluno) AS total_alunos
FROM monitoria m
JOIN aula_monitoria am ON am.id_monitoria = m.id_monitoria
JOIN presenca p ON p.id_aula = am.id_aula
GROUP BY m.disciplina;
"""

execute_read_query(connection, query)
# Out:
# []

# %% [markdown]
# **CONSULTA 2**
#
# * **Objetivo da consulta (contexto de PI3):** Mostrar quais as postagens no blog com sua determinada monitoria.
# * **Descrição da ação esperada ao rodar a consulta:** A consulta retorna a disiciplina da monitoria, o nome do aluno, o conteudo e a data da postagem.

# %%
query = """
SELECT m.disciplina AS Monitoria, pd.nome_usuario AS Aluno, pd.conteudo AS Conteudo, pd.data_postagem AS Data_Postagem
  FROM postagem_discussao pd
  JOIN blog_monitoria bm ON pd.id_blog = bm.id_blog
  JOIN monitoria m ON m.id_monitoria = bm.id_monitoria
  ;
"""
execute_read_query(connection, query)
# Out:
# [('Banco de Dados',
#   'Gustavo Silva',
#   'Estou com dúvida em JOIN.',
#   '2026-06-24 15:00:00'),
#  ('Matemática',
#   'Marina Costa',
#   'Alguém entendeu derivada?',
#   '2026-06-24 16:00:00'),
#  ('Banco de Dados',
#   'Lucas Almeida',
#   'Posso ajudar na dúvida sobre JOIN.',
#   '2026-06-24 17:00:00'),
#  ('Banco de Dados',
#   'Gustavo Silva',
#   'Estou com dúvida em JOIN.',
#   '2026-06-24 15:00:00'),
#  ('Matemática',
#   'Marina Costa',
#   'Alguém entendeu derivada?',
#   '2026-06-24 16:00:00'),
#  ('Banco de Dados',
#   'Lucas Almeida',
#   'Posso ajudar na dúvida sobre JOIN.',
#   '2026-06-24 17:00:00')]

# %% [markdown]
# ## Atividade 02
#
# Crie uma consulta relevante para sua aplicação em PI3 que envolva três entidades distintas. Descreva a ação esperada e justifique o contexto na aplicação de PI3.

# %% [markdown]
# **CONSULTA COM 3 ENTIDADES**
#
# > Adicionar aspas
#
#
#
# * **Objetivo da consulta (contexto de PI3):**Exibir os alunos presentes nas aulas de monitoria, informando a disciplina, a data e o horário de cada aula.
# * **Descrição da ação esperada ao rodar a consulta:** A consulta reúne informações de diferentes tabelas do banco de dados para apresentar quais alunos participaram das aulas de monitoria, facilitando o acompanhamento da frequência e da organização das monitorias.

# %%
query = """
SELECT
    m.disciplina AS Monitoria,
    am.data_aula AS Data_Aula,
    m.horario AS Horario,
    u.nome AS Aluno
FROM monitoria m
JOIN aula_monitoria am ON am.id_monitoria = m.id_monitoria
JOIN presenca p ON p.id_aula = am.id_aula
JOIN usuario u ON p.ra_aluno = u.ra
WHERE m.disciplina = 'Matemática';
"""

execute_read_query(connection, query)
# Out:
# [('Matemática', '2026-06-22', '10:00', 'Gustavo Silva')]

# %% [markdown]
# ## Atividade 03
#
# Crie uma view relevante para sua aplicação em PI3. Descreva a ação esperada na consulta dentro de sua view e, ao justificar o contexto, informe também por que a ação é tão recorrente no seu PI3 a ponto de precisar de uma view.

# %% [markdown]
# * **Justificativa para que a consulta seja uma View (Contexto de PI3):** A listagem de aulas e disciplinas das monitorias é utilizada frequentemente no sistema para exibição de quais delas estão acontecendo aos alunos, tornando útil salvar essa consulta como uma view.
# * **Descrição da ação esperada ao rodar a consulta:** A view retorna a data e o local das aulas de todas as monitorias.

# %%
query = """
CREATE VIEW vw_horarios_monitoria AS
SELECT
    m.disciplina AS Disciplina,
    m.horario AS Horario,
    m.local AS Local
FROM monitoria m;
"""

execute_query(connection, query)
# Out:
# Query CREATE VIEW vw_horarios_monitoria AS
# SELECT
#     m.disciplina AS Disciplina,
#     m.horario AS Horario,
#     m.local AS Local
# FROM monitoria m; executada.

# %%
query = """
SELECT * FROM vw_horarios_monitoria;
"""

execute_read_query(connection, query)
# Out:
# [('Banco de Dados', '14:00', 'Lab 01'),
#  ('Matemática', '10:00', 'Sala 12'),
#  ('Programação Web', '16:00', 'Lab 02'),
#  ('Banco de Dados', '14:00', 'Lab 01'),
#  ('Matemática', '10:00', 'Sala 12'),
#  ('Programação Web', '16:00', 'Lab 02')]

# %% [markdown]
# ## Atividade 04
#
# Crie um procedure relevante para sua aplicação em PI3. Descreva a ação esperada ao executar a procedure e, ao justificar o contexto, explique por que essa ação é tão recorrente no seu PI3 a ponto de precisar de uma procedure.

# %% [markdown]
# * **Justificativa para que a operação seja um Procedure (Contexto de PI3):** O cadastro de monitorias é uma ação recorrente no sistema, sendo útil encapsular essa funcionalidade em uma procedure.
# * **Descrição da ação esperada ao executar o procedure:** A procedure realiza o cadastro de uma nova monitoria no banco de dados.

# %%
def registrar_monitoria(connection, disciplina, local, horario, ra_monitor):

    query = f"""
    INSERT INTO monitoria
    (disciplina, local, horario, ra_monitor)

    VALUES
    ('{disciplina}', '{local}', '{horario}', {ra_monitor});
    """

    execute_query(connection, query)

# %%
registrar_monitoria(
    connection,
    "Programação Web",
    "Laboratório 03",
    "16:00",
    12345
)
# Out:
# Query INSERT INTO monitoria executada.
# 1 linha(s) afetadas

# %% [markdown]
# ## Atividade 05
#
# Crie uma function relevante para sua aplicação em PI3.
# Descreva o valor esperado como retorno ao executar a function e, ao justificar o contexto, explique por que é importante ter essa lógica encapsulada para uso recorrente no seu PI3.

# %% [markdown]
# * **Justificativa para que a operação seja uma Function (Contexto de PI3):** A Function foi criada para classificar automaticamente a frequência dos alunos com base na quantidade de presenças registradas. Dessa forma, a mesma lógica pode ser reutilizada em diferentes partes do sistema, evitando repetição de código.
#
# * **Descrição da operação realizada e valor retornado pela Function:** A Function recebe a quantidade de presenças de um aluno e retorna uma classificação indicando se sua frequência é baixa, regular ou excelente.

# %%
def avaliar_frequencia(total_presencas):

    if total_presencas == 0:
        return "Sem Presença"

    elif total_presencas <= 2:
        return "Frequência Regular"

    else:
        return "Frequência Excelente"

# %%
query = """
SELECT
    u.nome AS Aluno,
    COUNT(p.id_presenca) AS Total_Presencas
FROM usuario u
JOIN aluno a ON u.ra = a.ra
JOIN presenca p ON a.ra = p.ra_aluno
GROUP BY u.nome;
"""

resultado = execute_read_query(connection, query)

# %% [markdown]
# ## Atividade 06
#
# Crie um trigger relevante para sua aplicação em PI3.
# Descreva o evento que aciona o trigger e, ao justificar o contexto, explique por que essa automação é necessária para manter a integridade ou eficiência do seu PI3.

# %% [markdown]
# * **Justificativa para que a operação seja um Trigger (Contexto de PI3): ESCREVA**O Trigger foi criado para automatizar o envio de notificações sempre que um novo comunicado for cadastrado no sistema. Dessa forma, os usuários podem ser informados imediatamente sem necessidade de intervenção manual.
# * **Descrição do evento que dispara o Trigger e das operações que ele executa: ESCREVA**O Trigger é acionado após a inserção de um novo comunicado (AFTER INSERT). Quando isso ocorre, uma nova notificação é criada automaticamente na tabela de notificações.

# %%
query = """
CREATE TRIGGER trg_notificar_comunicado
AFTER INSERT ON comunicado
BEGIN
    INSERT INTO notificacao
    (titulo, conteudo, data_publicacao)

    VALUES
    (
        'Novo Comunicado',
        'Um novo comunicado foi publicado.',
        CURRENT_TIMESTAMP
    );
END;
"""

execute_query(connection, query)
# Out:
# Query CREATE TRIGGER trg_notificar_comunicado
# AFTER INSERT ON comunicado
# BEGIN
#     INSERT INTO notificacao executada.

# %%
query = """
INSERT INTO comunicado
(titulo, conteudo)

VALUES
(
    'Aviso Importante',
    'A monitoria de Banco de Dados foi alterada.'
);
"""

execute_query(connection, query)
# Out:
# Erro: 'NOT NULL constraint failed: comunicado.data_publicacao'
